# %% [markdown]
# ### Classes and object
# ##### OOP is a programming paradigm that uses "objects" to design application and computer programs. OOP allows for modeling real world scenarios using classes and objects.

# %%
# a class is a blue print for creating objects. Attributes, methods

class Car:
    pass
audi = Car()
bmw = Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
#instance variable and methods

class Dog:
##constructor
    def __init__(self, name, age):
        self.name1= name
        self.age1 = age
#create object
dog1 = Dog("XOXO",3)
cat = Dog("Zoha",3)
print(dog1.name1)
print(dog1.age1)

print(cat.name1)
print(cat.age1)
# Out:
# XOXO
# 3
# Zoha
# 3

# %%
#define a class with instance methods
class Dog:
    def __init__(self,name, age):
        self.name = name
        self.age = age
    ##instance methods
    def bark(self):
        print(f"{self.name} says woof")
dog1 = Dog("xoxo",2)
dog1.bark()

dog2 = Dog("Zoha",3)
dog2.bark()
# Out:
# xoxo says woof
# Zoha says woof

# %%
##modeling a Bank account
#define a class for bank account
class Bank:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance+=amount
        print(f"{amount } is deposited. New balance is {self.balance}")
    def withdraw(self, amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New Balance is {self.balance}")
    def get_balance(self):
        return self.balance
#create an account/object
account = Bank("Zobayer",5000)
print(account.balance)
# Out:
# 5000

# %%
#call instance methods
account.deposit(100)
# Out:
# 100 is deposited. New balance is 5100

# %%
account.withdraw(200)
# Out:
# 200 is withdrawn. New Balance is 4900

# %%
print(account.get_balance())
# Out:
# 4900

# %%
class Bank_account:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance
    def deposit(self, amount):
        self.balance+=amount
        print(f"{amount} is deposited. New Balance is {self.balance}")
    def withdraw(self, amount):
        if amount>self.balance:
            print("Insufficient Funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn!. New Balance is {self.balance}")
    def get_amount(self):
        return self.balance
#create an account/object
account = Bank_account("Zobayer", 4000)
print(account.owner)
print(account.balance)
# Out:
# Zobayer
# 4000

# %%
account.deposit(100)
# Out:
# 100 is deposited. New Balance is 4100

# %%
account.withdraw(200)
# Out:
# 200 is withdrawn!. New Balance is 3900

# %%
account.get_amount()
# Out:
# 3900
