# %% [markdown]
# #### SQL and SQLite
# SQL(Structured Query Language) is a standard language for managing and manipulating relational databases. SQLite is a self-contained, serverless, and zero-configuration database engine that is widely used for embedded database systems. In this lesson, we will cover the basics of SQL and SQLite, including creating databases, tables and performing various SQL operations.

# %%
import sqlite3

# %%
## connect to an SQLite database
connection= sqlite3.connect('example.db')
connection

# %%
cursor = connection.cursor()

# %%
# create a table
cursor.execute('''
create Table if not exists employees(
                id integer Primary key,
                name text Not Null,
                age Integer,
                department text)
''')
## commit the changes
connection.commit()

# %%
cursor.execute('''
select * from employees
''')

# %%
cursor.execute('''
insert into employees(name, age,department)
                values('Zoba',25,'CSE')     
               ''')

cursor.execute('''
insert into employees(name, age,department)
                values('Chow',24,'NFE')     
               ''')

cursor.execute('''
insert into employees(name, age,department)
                values('Ray',23,'SWE')     
               ''')
##commit the changes
connection.commit()

# %%
#query the data from the table
cursor.execute('select * from employees')
rows= cursor.fetchall()

#print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'Zoba', 25, 'CSE')
# (2, 'Zoba', 25, 'CSE')
# (3, 'Chow', 24, 'NFE')
# (4, 'Ray', 23, 'SWE')
# (5, 'Zoba', 25, 'CSE')
# (6, 'Chow', 24, 'NFE')
# (7, 'Ray', 23, 'SWE')
# (8, 'Zoba', 25, 'CSE')
# (9, 'Chow', 24, 'NFE')
# (10, 'Ray', 23, 'SWE')
# (11, 'Zoba', 25, 'CSE')
# (12, 'Chow', 24, 'NFE')
# (13, 'Ray', 23, 'SWE')
# (14, 'Zoba', 25, 'CSE')
# (15, 'Chow', 24, 'NFE')
# (16, 'Ray', 23, 'SWE')
# (17, 'Zoba', 25, 'CSE')
# (18, 'Chow', 24, 'NFE')
# (19, 'Ray', 23, 'SWE')

# %%
# update the data in the table
cursor.execute('''
               update employees
               set age=34
               where name='Ray'
               ''')
connection.commit()

# %%
#query the data from the table
cursor.execute('select * from employees')
rows= cursor.fetchall()

#print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'Zoba', 25, 'CSE')
# (2, 'Zoba', 25, 'CSE')
# (3, 'Chow', 24, 'NFE')
# (4, 'Ray', 34, 'SWE')
# (5, 'Zoba', 25, 'CSE')
# (6, 'Chow', 24, 'NFE')
# (7, 'Ray', 34, 'SWE')
# (8, 'Zoba', 25, 'CSE')
# (9, 'Chow', 24, 'NFE')
# (10, 'Ray', 34, 'SWE')
# (11, 'Zoba', 25, 'CSE')
# (12, 'Chow', 24, 'NFE')
# (13, 'Ray', 34, 'SWE')
# (14, 'Zoba', 25, 'CSE')
# (15, 'Chow', 24, 'NFE')
# (16, 'Ray', 34, 'SWE')
# (17, 'Zoba', 25, 'CSE')
# (18, 'Chow', 24, 'NFE')
# (19, 'Ray', 34, 'SWE')

# %%
#delete the data from the table
cursor.execute('''
               delete from employees
               where name='Chow'
               ''')
connection.commit()

# %%
#query the data from the table
cursor.execute('select * from employees')
rows= cursor.fetchall()

#print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'Zoba', 25, 'CSE')
# (2, 'Zoba', 25, 'CSE')
# (4, 'Ray', 34, 'SWE')
# (5, 'Zoba', 25, 'CSE')
# (7, 'Ray', 34, 'SWE')
# (8, 'Zoba', 25, 'CSE')
# (10, 'Ray', 34, 'SWE')
# (11, 'Zoba', 25, 'CSE')
# (13, 'Ray', 34, 'SWE')
# (14, 'Zoba', 25, 'CSE')
# (16, 'Ray', 34, 'SWE')
# (17, 'Zoba', 25, 'CSE')
# (19, 'Ray', 34, 'SWE')

# %%
#working with sales data
#connect to an SQLite database
connection = sqlite3.connect('sales_data.db')
cursor = connection.cursor()

#create a table for sales data

cursor.execute('''
               create table if not exists sales(
                   id integer primary key,
                   date text not null,
                   product text not null,
                   sales integer,
                   region text
               )
               
               ''')
#insert data into sales table
sales_data = [
    ('2026-05-23', 'product1', 100, 'North'),
    ('2026-05-24', 'product2', 140, 'South'),
]

cursor.executemany('''
        insert into sales(date, product, sales, region)      
        values(?,?,?,?)     
                   ''',sales_data)
connection.commit()

# %%
#query the data from the table
cursor.execute('select * from sales')
rows= cursor.fetchall()

#print the queried data
for row in rows:
    print(row)
# Out:
# (1, '2026-05-23', 'product1', 100, 'North')
# (2, '2026-05-24', 'product2', 140, 'South')

# %%
#close the connection 
connection.close()
