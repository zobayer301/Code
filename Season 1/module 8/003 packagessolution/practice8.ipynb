# %%
import math
print(math.sqrt(25))
print(math.sin(math.radians(45)))
# Out:
# 5.0
# 0.7071067811865476

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-04-19 14:07:38.846747

# %%
from math import sqrt, pow
print(math.sqrt(16))# 4
print(math.pow(2,3))# 8
# Out:
# 4.0
# 8.0

# %%
try:
    import non_existent_module
except ImportError as e:
    print(f"Error importing module: {e}")
# Out:
# Error importing module: No module named 'non_existent_module'

# %%
import os
os.mkdir('new_directory')
print(os.listdir('.'))

#remove the newly created directory
os.rmdir('new_directory')
print(os.listdir('.'))
# Out:
# ['new_directory', 'packagesquestion.ipynb', 'packagessolution.ipynb', 'practice8.ipynb']
# ['packagesquestion.ipynb', 'packagessolution.ipynb', 'practice8.ipynb']
