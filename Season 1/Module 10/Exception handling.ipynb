# %% [markdown]
# ##### Understanding Exception
# Exception handling in python allows you to handle errors gracefully and take corrective actions without stopping the execution of the program.

# %% [markdown]
# ##### What are Exceptions?
# Exception are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
#
# ###### 1. ZeroDivisionError: Dividing by zero
# ###### 2. FileNotFoundError: File not found
# ###### 3. ValueError: Invalid value
# ###### 4. TypeError: Invalid type

# %%
a= b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a= b
#
# NameError: name 'b' is not defined

# %%
### Exception try, except block
try:
    a = b
except:
    print("the variable is not assigned")
# Out:
# the variable is not assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
    print(int(result))
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the dominator greater than zero")
# Out:
# division by zero
# Please enter the dominator greater than zero

# %%
try:
    result = 1/2
    a = b
    print(int(result))
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the dominator greater than zero")
except Exception as ex1:
    print(ex1)
    print('Main exception got caught here')
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
   num = int(input("Enter a number"))
   result = 10/num
except ValueError:
    print("Enter a Valid number") 
except ZeroDivisionError:
    print("Enter the dominator greater than 0")
except Exception as ex:
    print(ex)
# Out:
# Enter the dominator greater than 0

# %%
## try, except, else block
try:
   num = int(input("Enter a number"))
   result = 10/num
except ValueError:
    print("Enter a Valid number") 
except ZeroDivisionError:
    print("Enter the dominator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
# Out:
# the result is 1.0

# %%
# try, except, else and finally
try:
   num = int(input("Enter a number"))
   result = 10/num
except ValueError:
    print("Enter a Valid number") 
except ZeroDivisionError:
    print("Enter the dominator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
finally:
    print("EXECUTION IS COMPLETED! THANK YOU!!")
# Out:
# Enter the dominator greater than 0
# EXECUTION IS COMPLETED! THANK YOU!!

# %%
# file handling and exception handling
try:
    file= open('example1.txt','r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print('the file does not exists')

finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("file close")
# Out:
# file close
