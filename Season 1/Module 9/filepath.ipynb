# %%
import os
cwd = os.getcwd()
print(f'current working directory is {cwd}')
# Out:
# current working directory is d:\Python\Module 9

# %%
## create a new directory
new = 'package'
os.mkdir(new)
print(f"Directory'{new}' create")
# Out:
# Directory'package' create

# %%
#listing files and directories
items  = os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'file operation.ipynb', 'filepath.ipynb', 'package']

# %%
### joining path
dir_name= "folder"
file_name="file.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name= "folder"
file_name="file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# d:\Python\Module 9\folder\file.txt

# %%
path= 'example1.txt'
if os.path.exists(path):
    print(f"The path'{path}' exits")
else:
    print(f"The path '{path}' does not exist")
# Out:
# The path 'example1.txt' does not exist

# %%
#checking if a path is a file or directory
import os

path = 'example.txt'
path1 = 'example.bin'

if os.path.isfile(path):
    print(f"the path '{path}' is a file")
elif os.path.isdir(path):
    print(f"the path '{path}' is a directory")
else:
    print(f"the path'{path}' is neither a file nor a directory")
# Out:
# the path 'example.txt' is a file
