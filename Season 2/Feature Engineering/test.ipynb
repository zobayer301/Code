# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
A,b= make_classification(n_samples=1000, n_redundant=0, n_clusters_per_class=1, weights=[0.90], random_state=12)

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(A, columns=['f1', 'f2'])
df2 = pd.DataFrame(b, columns=['target'])

final_df = pd.concat([df1, df2], axis=1)
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df1 = pd.DataFrame(A, columns=['f1', 'f2'])
#       2 df2 = pd.DataFrame(b, columns=['target'])
#       4 final_df = pd.concat([df1, df2], axis=1)
#
# File c:\Users\Zobayer\.conda\envs\python_eda\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)    824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
# ...
