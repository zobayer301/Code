# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv('Algerian_forest_fires_dataset.csv')
dataset.head()
# Out:
#    Unnamed: 0 day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  \
# 0           0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3
# 1           1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1
# 2           2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3
# 3           3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0
# 4           4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2
#
#    BUI  FWI    Classes
# 0  3.4  0.5  not fire
# 1  3.9  0.4  not fire
# 2  2.7  0.1  not fire
# 3  1.7    0  not fire
# 4  3.9  0.5  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   247 non-null    int64
#  1   day          246 non-null    object
#  2   month        245 non-null    object
#  3   year         245 non-null    object
#  4   Temperature  245 non-null    object
#  5    RH          245 non-null    object
#  6    Ws          245 non-null    object
#  7   Rain         245 non-null    object
#  8   FFMC         245 non-null    object
#  9   DMC          245 non-null    object
#  10  DC           245 non-null    object
#  11  ISI          245 non-null    object
#  12  BUI          245 non-null    object
#  13  FWI          245 non-null    object
#  14  Classes      244 non-null    object
# dtypes: int64(1), object(14)
# memory usage: 29.1+ KB

# %% [markdown]
# ### data cleaning

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#      Unnamed: 0                            day month  year Temperature   RH  \
# 122         122                            NaN   NaN   NaN         NaN  NaN
# 123         123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN
# 168         168                             14     7  2012          37   37
#
#       Ws Rain   FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122  NaN   NaN   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123  NaN   NaN   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168   18   0.2  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
dataset.loc[:123,'Region'] = 0
dataset.loc[123:,'Region'] = 1

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   247 non-null    int64
#  1   day          246 non-null    object
#  2   month        245 non-null    object
#  3   year         245 non-null    object
#  4   Temperature  245 non-null    object
#  5    RH          245 non-null    object
#  6    Ws          245 non-null    object
#  7   Rain         245 non-null    object
#  8   FFMC         245 non-null    object
#  9   DMC          245 non-null    object
#  10  DC           245 non-null    object
#  11  ISI          245 non-null    object
#  12  BUI          245 non-null    object
#  13  FWI          245 non-null    object
#  14  Classes      244 non-null    object
#  15  Region       247 non-null    float64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 31.0+ KB

# %%
dataset[['Region']] = dataset[['Region']].astype(int)

# %%
dataset.head()
# Out:
#    Unnamed: 0 day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  \
# 0           0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3
# 1           1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1
# 2           2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3
# 3           3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0
# 4           4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2
#
#    BUI  FWI    Classes    Region
# 0  3.4  0.5  not fire          0
# 1  3.9  0.4  not fire          0
# 2  2.7  0.1  not fire          0
# 3  1.7    0  not fire          0
# 4  3.9  0.5  not fire          0

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0     0
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# Region         0
# dtype: int64

# %%
##remove the null values
df = dataset.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#    Unnamed: 0 day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  \
# 0           0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3
# 1           1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1
# 2           2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3
# 3           3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0
# 4           4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2
#
#    BUI  FWI    Classes    Region
# 0  3.4  0.5  not fire          0
# 1  3.9  0.4  not fire          0
# 2  2.7  0.1  not fire          0
# 3  1.7    0  not fire          0
# 4  3.9  0.5  not fire          0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      Unnamed: 0  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  \
# 122         124  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC
#
#      DC  ISI  BUI  FWI  Classes    Region
# 122  DC  ISI  BUI  FWI  Classes         1

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#      Unnamed: 0 day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  \
# 122         125   1     6  2012          32  71  12   0.7  57.1  2.5  8.2
#
#      ISI  BUI  FWI    Classes    Region
# 122  0.6  2.8  0.2  not fire          1

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'day', 'month', 'year', 'Temperature', ' RH', ' Ws',
#        'Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ',
#        'Region'],
#       dtype='object')

# %%
## fix spaces in column names and remove duplicate labels
df.columns = df.columns.str.strip()
df = df.loc[:, ~df.columns.duplicated()].copy()
df.columns
# Out:
# Index(['Unnamed: 0', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
## changes the required columns as integer data type
df[['day','month','year','Temperature','RH','Ws']] = df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   243 non-null    int64
#  1   day          243 non-null    int64
#  2   month        243 non-null    int64
#  3   year         243 non-null    int64
#  4   Temperature  243 non-null    int64
#  5   RH           243 non-null    int64
#  6   Ws           243 non-null    int64
#  7   Rain         243 non-null    object
#  8   FFMC         243 non-null    object
#  9   DMC          243 non-null    object
#  10  DC           243 non-null    object
#  11  ISI          243 non-null    object
#  12  BUI          243 non-null    object
#  13  FWI          243 non-null    object
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    int64
# dtypes: int64(8), object(8)
# memory usage: 30.5+ KB

# %%
##changing the other columns to float datatype
objects = [features for features in df.columns if df[features].dtypes =='O']

# %%
for i in objects:
    if i!='Classes':
        df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   243 non-null    int64
#  1   day          243 non-null    int64
#  2   month        243 non-null    int64
#  3   year         243 non-null    int64
#  4   Temperature  243 non-null    int64
#  5   RH           243 non-null    int64
#  6   Ws           243 non-null    int64
#  7   Rain         243 non-null    float64
#  8   FFMC         243 non-null    float64
#  9   DMC          243 non-null    float64
#  10  DC           243 non-null    float64
#  11  ISI          243 non-null    float64
#  12  BUI          243 non-null    float64
#  13  FWI          243 non-null    float64
#  14  Classes      243 non-null    object
#  15  Region       243 non-null    int64
# dtypes: float64(7), int64(8), object(1)
# memory usage: 30.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         day       month    year  Temperature          RH  \
# count  243.000000  243.000000  243.000000   243.0   243.000000  243.000000
# mean   122.814815   15.761317    7.502058  2012.0    32.152263   62.041152
# std     71.976599    8.842552    1.114793     0.0     3.628039   14.828160
# min      0.000000    1.000000    6.000000  2012.0    22.000000   21.000000
# 25%     60.500000    8.000000    7.000000  2012.0    30.000000   52.500000
# 50%    121.000000   16.000000    8.000000  2012.0    32.000000   63.000000
# 75%    185.500000   23.000000    8.000000  2012.0    35.000000   73.500000
# max    246.000000   31.000000    9.000000  2012.0    42.000000   90.000000
#
#                Ws        Rain        FFMC         DMC          DC         ISI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean    15.493827    0.762963   77.842387   14.680658   49.430864    4.742387
# std      2.811385    2.003207   14.349641   12.393040   47.665606    4.154234
# min      6.000000    0.000000   28.600000    0.700000    6.900000    0.000000
# 25%     14.000000    0.000000   71.850000    5.800000   12.350000    1.400000
# 50%     15.000000    0.000000   83.300000   11.300000   33.100000    3.500000
# 75%     17.000000    0.500000   88.300000   20.800000   69.100000    7.250000
# max     29.000000   16.800000   96.000000   65.900000  220.400000   19.000000
#
#               BUI         FWI      Region
# count  243.000000  243.000000  243.000000
# mean    16.690535    7.035391    0.497942
# std     14.228421    7.440568    0.501028
# min      1.100000    0.000000    0.000000
# 25%      6.000000    0.700000    0.000000
# 50%     12.400000    4.200000    0.000000
# 75%     22.650000   11.450000    1.000000
# max     68.000000   31.100000    1.000000

# %%
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI      Classes  Region
# 0  1.3  3.4  0.5  not fire          0
# 1  1.0  3.9  0.4  not fire          0
# 2  0.3  2.7  0.1  not fire          0
# 3  0.0  1.7  0.0  not fire          0
# 4  1.2  3.9  0.5  not fire          0

# %%
# let save the clean dataset
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv')

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Unnamed: 0  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0           0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1           1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2           2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3           3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4           4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
#encoding of the categories in classes
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.tail()
# Out:
#      Unnamed: 0  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 238         242           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239         243           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240         244           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241         245           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242         246           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#      Classes  Region
# 238        1       1
# 239        0       1
# 240        0       1
# 241        0       1
# 242        0       1

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
#plot density plot for all features
plt.style.use('seaborn-v0_8')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
#percentage for pie chart
percentage = df_copy['Classes'].value_counts(normalize=True)*100
percentage
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
#plotting pie chart
classlabels = ['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pie(percentage, labels = classlabels,autopct='%1.1f%%')
plt.title("Pie Chart for Classes")
plt.show()

# %%
#correlation
df_copy.corr()
# Out:
#              Unnamed: 0  Temperature        RH        Ws      Rain      FFMC  \
# Unnamed: 0     1.000000     0.217944 -0.378777 -0.171101 -0.031556  0.227876
# Temperature    0.217944     1.000000 -0.651400 -0.284510 -0.326492  0.676568
# RH            -0.378777    -0.651400  1.000000  0.244048  0.222356 -0.644873
# Ws            -0.171101    -0.284510  0.244048  1.000000  0.171506 -0.166548
# Rain          -0.031556    -0.326492  0.222356  0.171506  1.000000 -0.543906
# FFMC           0.227876     0.676568 -0.644873 -0.166548 -0.543906  1.000000
# DMC            0.258653     0.485687 -0.408519 -0.000721 -0.288773  0.603608
# DC             0.055496     0.376284 -0.226941  0.079135 -0.298023  0.507397
# ISI            0.281470     0.603871 -0.686667  0.008532 -0.347484  0.740007
# BUI            0.180624     0.459789 -0.353841  0.031438 -0.299852  0.592011
# FWI            0.252877     0.566670 -0.580957  0.032368 -0.324422  0.691132
# Classes        0.176687     0.516015 -0.432161 -0.069964 -0.379097  0.769492
# Region         0.871129     0.269555 -0.402682 -0.181160 -0.040013  0.222241
#
#                   DMC        DC       ISI       BUI       FWI   Classes  \
# Unnamed: 0   0.258653  0.055496  0.281470  0.180624  0.252877  0.176687
# Temperature  0.485687  0.376284  0.603871  0.459789  0.566670  0.516015
# RH          -0.408519 -0.226941 -0.686667 -0.353841 -0.580957 -0.432161
# Ws          -0.000721  0.079135  0.008532  0.031438  0.032368 -0.069964
# Rain        -0.288773 -0.298023 -0.347484 -0.299852 -0.324422 -0.379097
# FFMC         0.603608  0.507397  0.740007  0.592011  0.691132  0.769492
# DMC          1.000000  0.875925  0.680454  0.982248  0.875864  0.585658
# DC           0.875925  1.000000  0.508643  0.941988  0.739521  0.511123
# ISI          0.680454  0.508643  1.000000  0.644093  0.922895  0.735197
# BUI          0.982248  0.941988  0.644093  1.000000  0.857973  0.586639
# FWI          0.875864  0.739521  0.922895  0.857973  1.000000  0.719216
# Classes      0.585658  0.511123  0.735197  0.586639  0.719216  1.000000
# Region       0.192089 -0.078734  0.263197  0.089408  0.197102  0.162347
#
#                Region
# Unnamed: 0   0.871129
# Temperature  0.269555
# RH          -0.402682
# Ws          -0.181160
# Rain        -0.040013
# FFMC         0.222241
# DMC          0.192089
# DC          -0.078734
# ISI          0.263197
# BUI          0.089408
# FWI          0.197102
# Classes      0.162347
# Region       1.000000

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
#box plot
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: ylabel='FWI'>

# %%
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI      Classes  Region
# 0  1.3  3.4  0.5  not fire          0
# 1  1.0  3.9  0.4  not fire          0
# 2  0.3  2.7  0.1  not fire          0
# 3  0.0  1.7  0.0  not fire          0
# 4  1.2  3.9  0.5  not fire          0

# %%
#monthly fire analysis
dftemp = df.loc[df['Region'] == 1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes',data=df)
# Out:
# <Axes: xlabel='month', ylabel='count'>
